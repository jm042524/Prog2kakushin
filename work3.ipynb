# %% [markdown]
# <a href="https://colab.research.google.com/github/jm042524/Prog2kakushin/blob/main/work3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##テーマ：OpenCv
# opencvを利用して、手で操作できる画面上のエアホッケーを作る。(colabで実行不可能なので、変えます)

# %%
pip install wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !wget --no-check-certificate 'https://drive.google.com/uc?export=download&id=12daqnZEtG4Mw2wFAiA7iNUky0NVsyHt1' -O haar_cascades_face.xml
# Out:
# --2023-01-19 04:04:27--  https://drive.google.com/uc?export=download&id=12daqnZEtG4Mw2wFAiA7iNUky0NVsyHt1
# Resolving drive.google.com (drive.google.com)... 142.251.107.139, 142.251.107.138, 142.251.107.100, ...
# Connecting to drive.google.com (drive.google.com)|142.251.107.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘haar_cascades_face.xml’
#
# haar_cascades_face.     [ <=>                ]   2.23K  --.-KB/s    in 0s
#
# 2023-01-19 04:04:27 (23.2 MB/s) - ‘haar_cascades_face.xml’ saved [2285]

# %%
# !wget --no-check-certificate 'https://drive.google.Acom/uc?export=download&id=1ROWsk_58LRVV1T3X-PFJ_yLh2OnhQ9ok' -O Frank_Ocean.zip
# !unzip -o Frank_Ocean.zip
# Out:
# --2023-01-19 04:14:12--  https://drive.google.com/uc?export=download&id=1ROWsk_58LRVV1T3X-PFJ_yLh2OnhQ9ok
# Resolving drive.google.com (drive.google.com)... 142.251.107.138, 142.251.107.100, 142.251.107.102, ...
# Connecting to drive.google.com (drive.google.com)|142.251.107.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-14-ao-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/862trvfumcf4ini96mfpvseck9ben7gb/1674101625000/15307937988973890921/*/1ROWsk_58LRVV1T3X-PFJ_yLh2OnhQ9ok?e=download&uuid=746d1ee8-5eae-444b-8fa0-e1b80e9e3091 [following]
# ...
# --2023-01-19 04:14:13--  https://doc-14-ao-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/862trvfumcf4ini96mfpvseck9ben7gb/1674101625000/15307937988973890921/*/1ROWsk_58LRVV1T3X-PFJ_yLh2OnhQ9ok?e=download&uuid=746d1ee8-5eae-444b-8fa0-e1b80e9e3091
# ...

# %%
# !wget --no-check-certificate 'https://drive.google.com/uc?export=download&id=1dvuDBIR1AqK-V5pf_WMycor-p4T3NVyO' -O jm_smile.jpg
# Out:
# --2023-01-19 08:07:52--  https://drive.google.com/uc?export=download&id=1dvuDBIR1AqK-V5pf_WMycor-p4T3NVyO
# Resolving drive.google.com (drive.google.com)... 173.194.214.101, 173.194.214.138, 173.194.214.139, ...
# Connecting to drive.google.com (drive.google.com)|173.194.214.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0o-ao-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/0100a0elq5of52q2sq6ljcektojeu0aj/1674115650000/15307937988973890921/*/1dvuDBIR1AqK-V5pf_WMycor-p4T3NVyO?e=download&uuid=58475708-8a96-4ff2-a366-47f68a68db76 [following]
# ...
# --2023-01-19 08:07:53--  https://doc-0o-ao-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/0100a0elq5of52q2sq6ljcektojeu0aj/1674115650000/15307937988973890921/*/1dvuDBIR1AqK-V5pf_WMycor-p4T3NVyO?e=download&uuid=58475708-8a96-4ff2-a366-47f68a68db76
# ...

# %%
"""from google.colab import drive
import os
drive.mount('/content/drive')"""
# Out:
# "from google.colab import drive\nimport os\ndrive.mount('/content/drive')"

# %%
"""!pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials"""
# Out:
# '!pip install -U -q PyDrive\nfrom pydrive.auth import GoogleAuth\nfrom pydrive.drive import GoogleDrive\nfrom google.colab import auth\nfrom oauth2client.client import GoogleCredentials'

# %%
"""auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive()"""
# Out:
# 'auth.authenticate_user()\ngauth = GoogleAuth()\ngauth.credentials = GoogleCredentials.get_application_default()\ndrive = GoogleDrive()'

# %%
"""downloaded = drive.CreateFile({'id':'https://drive.google.com/open?id='})
downloaded.GetContentFile("filename.fl")"""
# Out:
# 'downloaded = drive.CreateFile({\'id\':\'https://drive.google.com/open?id=\'})\ndownloaded.GetContentFile("filename.fl")'

# %%
import cv2 
from google.colab.patches import cv2_imshow

img = cv2.imread("unknown/3.jpg")
cv2_imshow(img)

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=RGB size=760x462 at 0x7F9C1912FFA0>
# <PIL.Image.Image image mode=L size=760x462 at 0x7F9C1912FFA0>

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

faces_rect = face_cascade.detectMultiScale(gray, scaleFactor = 1.1, minNeighbors=3)

print(f"Number of faces found = {len(faces_rect)}")

for (x,y,w,h) in faces_rect:
  cv2.rectangle(img, (x,y), (x+w, y+h), (0, 255, 0), thickness=2)

cv2_imshow(img)

cv2.waitKey(0)
# Out:
# Number of faces found = 1
# <PIL.Image.Image image mode=RGB size=760x462 at 0x7F9C1912FDF0>
# -1

# %%
import os
import cv2
import numpy as np

people = ["Frank_Ocean"]

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
features = []
labels = []

def create_train():
  for person in people:
    path = str(person)

    for i in range(1,11):
      img_path = f"{path}/{person}_{i}.jpg"
      
      img_array = cv2.imread(img_path)
      gray = cv2.cvtColor(img_array, cv2.COLOR_BGR2GRAY)

      faces_rect = face_cascade.detectMultiScale(gray, scaleFactor = 1.1, minNeighbors=6)
      for (x, y, w, h) in faces_rect:
        cv2.rectangle(img_array, (x,y), (x+w, y+h), (0, 255, 0), thickness=2)
        faces_roi = gray[y:y+h, x:x+w]
        features.append(faces_roi)
        labels.append(person)
        cv2_imshow(img_array)
      cv2.waitKey(0)
create_train()

# %%
print(f"Length of the features = {len(features)}")
print(f"Length of the labels = {len(labels)}")
# Out:
# Length of the features = 12
# Length of the labels = 12

# %%
pip install opencv-contrib-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
features = np.array(features, dtype = "object")
labels = np.array(labels)

recognizer = cv2.face.createLBPHFaceRecognizer()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-116-bad66f608947> in <module>
#       2 labels = np.array(labels)
#       3
# ----> 4 recognizer = cv2.face.createLBPHFaceRecognizer()
#
# AttributeError: module 'cv2.face' has no attribute 'createLBPHFaceRecognizer'
